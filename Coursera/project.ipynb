# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd

# Define the ticker symbol for Tesla
ticker_symbol = 'TSLA'

# Get data on this ticker
tesla_data = yf.Ticker(ticker_symbol)

# Get the historical prices for this ticker
tesla_hist = tesla_data.history(period="max")

# Reset the index of the historical data DataFrame
tesla_hist.reset_index(drop=True, inplace=True)

# Display the first five rows of the DataFrame
print(tesla_hist.head())
# Out:
#        Open      High       Low     Close     Volume  Dividends  Stock Splits
# 0  1.266667  1.666667  1.169333  1.592667  281494500        0.0           0.0
# 1  1.719333  2.028000  1.553333  1.588667  257806500        0.0           0.0
# 2  1.666667  1.728000  1.351333  1.464000  123282000        0.0           0.0
# 3  1.533333  1.540000  1.247333  1.280000   77097000        0.0           0.0
# 4  1.333333  1.333333  1.055333  1.074000  103003500        0.0           0.0

# %%
import matplotlib.pyplot as plt

def make_graph(stock_data):
    plt.figure(figsize=(14, 7))
    plt.plot(stock_data.index, stock_data['Close'], label='Tesla Stock Price', color='blue')
    plt.title('Tesla Stock Price Over Time')
    plt.xlabel('Date')
    plt.ylabel('Price ($)')
    plt.legend()
    plt.grid()
    plt.show()

# %%
make_graph(tesla_hist)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the page to be scraped
url = 'https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Send a GET request to the URL
response = requests.get(url, headers=headers)

# Parse the HTML content of the page
soup = BeautifulSoup(response.content, 'html.parser')

# Find the table containing the revenue data
table = soup.find_all('table', {'class': 'historical_data_table table'})

if table:
    # Extract the rows from the table
    rows = table[0].find_all('tr')
    revenue_data = []
    for row in rows:
        cols = row.find_all('td')
        cols = [col.text.strip() for col in cols]
        revenue_data.append(cols)

    revenue_df = pd.DataFrame(revenue_data[1:], columns=['Year', 'Amount'])

    print(revenue_df)

else:
    print("Table with class 'historical_data_table table' not found.")
# Out:
#     Year   Amount
# 0   2023  $96,773
# 1   2022  $81,462
# 2   2021  $53,823
# 3   2020  $31,536
# 4   2019  $24,578
# 5   2018  $21,461
# 6   2017  $11,759
# 7   2016   $7,000
# 8   2015   $4,046
# 9   2014   $3,198
# 10  2013   $2,013
# 11  2012     $413
# 12  2011     $204
# 13  2010     $117
# 14  2009     $112

# %%
revenue_df.tail(5)
# Out:
#     Year  Amount
# 10  2013  $2,013
# 11  2012    $413
# 12  2011    $204
# 13  2010    $117
# 14  2009    $112

# %%
# Define the ticker symbol for GameStop
ticker_symbol = 'GME'

# Get data on this ticker
gamestop_data = yf.Ticker(ticker_symbol)

# Get the historical prices for this ticker
gamestop_hist = gamestop_data.history(period="max")

# Display the first few rows of the dataframe
print(gamestop_hist.head())
# Out:
#                                Open      High       Low     Close    Volume  \
# Date
# 2002-02-13 00:00:00-05:00  1.620128  1.693350  1.603296  1.691667  76216000
# 2002-02-14 00:00:00-05:00  1.712707  1.716074  1.670626  1.683250  11021600
# 2002-02-15 00:00:00-05:00  1.683250  1.687458  1.658002  1.674834   8389600
# 2002-02-19 00:00:00-05:00  1.666418  1.666418  1.578047  1.607504   7410400
# 2002-02-20 00:00:00-05:00  1.615921  1.662210  1.603296  1.662210   6892800
#
#                            Dividends  Stock Splits
# Date
# 2002-02-13 00:00:00-05:00        0.0           0.0
# 2002-02-14 00:00:00-05:00        0.0           0.0
# 2002-02-15 00:00:00-05:00        0.0           0.0
# 2002-02-19 00:00:00-05:00        0.0           0.0
# 2002-02-20 00:00:00-05:00        0.0           0.0

# %%
import matplotlib.pyplot as plt

def make_graph(stock_data, title):
    plt.figure(figsize=(14, 7))
    plt.plot(stock_data.index, stock_data['Close'], label='GameStop Stock Price', color='green')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Price ($)')
    plt.legend()
    plt.grid()
    plt.show()

# %%
# Assuming gamestop_hist is your DataFrame containing GameStop stock data
make_graph(gamestop_hist, 'GameStop Stock Price Over Time')

# %%
import yfinance as yf
import pandas as pd

# Define the ticker symbol for GameStop
ticker_symbol = 'GME'

# Get data on this ticker
gme_data = yf.Ticker(ticker_symbol)

# Get the historical prices for this ticker
gme_hist = gme_data.history(period="max")

# %%
# Reset the index of the historical data DataFrame
gme_hist.reset_index(drop=True, inplace=True)

# Display the first five rows of the DataFrame
print(gme_hist.head())
# Out:
#        Open      High       Low     Close    Volume  Dividends  Stock Splits
# 0  1.620128  1.693350  1.603296  1.691666  76216000        0.0           0.0
# 1  1.712707  1.716074  1.670626  1.683251  11021600        0.0           0.0
# 2  1.683250  1.687458  1.658002  1.674834   8389600        0.0           0.0
# 3  1.666418  1.666418  1.578047  1.607504   7410400        0.0           0.0
# 4  1.615920  1.662210  1.603296  1.662210   6892800        0.0           0.0

# %%
# URL of the page to be scraped for GameStop revenue
url = 'https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Send a GET request to the URL
response = requests.get(url, headers=headers)
# Parse the HTML content of the page
soup = BeautifulSoup(response.content, 'html.parser')
# Find the table containing the revenue data
table = soup.find_all('table', {'class': 'historical_data_table table'})

if table:
    # Extract the rows from the table
    rows = table[0].find_all('tr')
    revenue_data = []
    for row in rows:
        cols = row.find_all('td')
        cols = [col.text.strip() for col in cols]
        revenue_data.append(cols)
        
    revenue_df2 = pd.DataFrame(revenue_data[1:], columns=['Year', 'Amount'])
    print(revenue_df2)
else:
    print("Table with class 'historical_data_table table' not found.")
# Out:
#     Year  Amount
# 0   2024  $5,273
# 1   2023  $5,927
# 2   2022  $6,011
# 3   2021  $5,090
# 4   2020  $6,466
# 5   2019  $8,285
# 6   2018  $8,547
# 7   2017  $7,965
# 8   2016  $9,364
# 9   2015  $9,296
# 10  2014  $9,040
# 11  2013  $8,887
# 12  2012  $9,551
# 13  2011  $9,474
# 14  2010  $9,078
# 15  2009  $8,806

# %%
# Display the last five rows of the gme_revenue DataFrame
print(revenue_df2.tail())
# Out:
#     Year  Amount
# 11  2013  $8,887
# 12  2012  $9,551
# 13  2011  $9,474
# 14  2010  $9,078
# 15  2009  $8,806

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming tesla_hist and revenue_data are already defined
# Convert revenue_data to DataFrame
revenue_df = pd.DataFrame(revenue_data[1:], columns=['Year', 'Amount'])

# Plotting Tesla stock prices
plt.figure(figsize=(14, 7))
plt.subplot(2, 1, 1)
plt.plot(tesla_hist.index, tesla_hist['Close'], label='Tesla Stock Price', color='blue')
plt.title('Tesla Stock Price')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()

# Plotting Tesla revenue
plt.subplot(2, 1, 2)
plt.plot(revenue_df['Year'], revenue_df['Amount'], label='Tesla Revenue', color='orange')
plt.title('Tesla Revenue')
plt.xlabel('Year')
plt.ylabel('Revenue ($)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Convert GameStop revenue_data to DataFrame
gamestop_revenue_df = pd.DataFrame(revenue_data[1:], columns=['Year', 'Amount'])

# Plotting GameStop stock prices
plt.figure(figsize=(14, 7))
plt.subplot(2, 1, 1)
plt.plot(gamestop_hist.index, gamestop_hist['Close'], label='GameStop Stock Price', color='green')
plt.title('GameStop Stock Price')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()

# Plotting GameStop revenue
plt.subplot(2, 1, 2)
plt.plot(gamestop_revenue_df['Year'], gamestop_revenue_df['Amount'], label='GameStop Revenue', color='red')
plt.title('GameStop Revenue')
plt.xlabel('Date')
plt.ylabel('Revenue ($)')
plt.legend()

plt.tight_layout()
plt.show()
