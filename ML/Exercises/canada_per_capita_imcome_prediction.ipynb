# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
capita_income = pd.read_csv('data/canada_per_capita_income.csv')
capita_income.tail()
# Out:
#     year  per capita income (US$)
# 42  2012              42665.25597
# 43  2013              42676.46837
# 44  2014              41039.89360
# 45  2015              35175.18898
# 46  2016              34229.19363

# %%
X_train=capita_income[['year']]
y_train=capita_income['per capita income (US$)']

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predict_data = pd.DataFrame({'year': [2020, 2021, 2022, 2023, 2024]})
model.predict(predict_data)
# Out:
# array([41288.69409442, 42117.15916964, 42945.62424486, 43774.08932009,
#        44602.55439531])

# %%
plt.xlabel('Year')
plt.ylabel('Per Capita Income (US$)')
plt.scatter(X_train, y_train, color='red', marker='*')
plt.plot(X_train, model.predict(X_train), color='blue')
